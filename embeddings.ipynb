# %%
import os
import openai
from scipy.spatial import distance
import plotly.express as px
from sklearn.cluster import KMeans
from umap import UMAP

# %%
from openai import OpenAI
client = OpenAI(api_key="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")
def get_embedding(text_to_embed):
    #Embed a line of text
    
    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=[text_to_embed]
    )
    # Extract the AI output embedding as a list of floats
    embedding=response.data[0].embedding
    
    return embedding

# %%
import pandas as pd

data_URL = "https://raw.githubusercontent.com/keitazoumana/Experimentation-Data/main/Musical_instruments_reviews.csv"

review_df = pd.read_csv(data_URL)

review_df.head(2)
# Out:
#        reviewerID        asin  \
# 0  A2IBPI20UZIR0U  1384719342
# 1  A14VAT5EAX3D9S  1384719342
#
#                                        reviewerName   helpful  \
# 0  cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                              Jake  [13, 14]
#
#                                           reviewText  overall summary  \
# 0  Not much to write about here, but it does exac...      5.0    good
# 1  The product does exactly as it should and is q...      5.0    Jake
#
#    unixReviewTime   reviewTime
# 0      1393545600  02 28, 2014
# 1      1363392000  03 16, 2013

# %%
review_df = review_df[["reviewText"]]
print("Data shape: {}".format(review_df.shape))
display(review_df.head(2))
# Out:
# Data shape: (10261, 1)
#                                           reviewText
# 0  Not much to write about here, but it does exac...
# 1  The product does exactly as it should and is q...

# %%
review_df = review_df.sample(100)
review_df['embedding'] = review_df['reviewText'].astype(str).apply(get_embedding)

#Make the index start from 0
review_df.reset_index(drop=True)
review_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[49], line 2
#       1 review_df = review_df.sample(100)
# ----> 2 review_df['embedding'] = review_df['reviewText'].astype(str).apply(get_embedding)
#       4 #Make the index start from 0
#       5 review_df.reset_index(drop=True)
#
# File e:\AI_Agent_Bootcamp_Ostad\myenv\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
# ...
